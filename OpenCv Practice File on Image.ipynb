# %% [markdown]
# ## Import Libraries:

# %%
#pip install opencv-python

# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading Images:

# %%
color_img = cv2.imread(r"lena.jpg",1)  # Here 1 is for the color image.
cv2.imshow('Color Image', color_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
color_img.shape
# Out:
# (512, 512, 3)

# %%
color_img.size
# Out:
# 786432

# %%
bw_img = cv2.imread(r"lena.jpg",0)  # Here 1 is for the color image.
cv2.imshow('Color Image', bw_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
bw_img.shape
# Out:
# (512, 512)

# %%
bw_img.size
# Out:
# 262144

# %% [markdown]
# ### Writing and saving an Image :

# %%
# Saving the Black n White Image
cv2.imwrite('lena BW.jpg', bw_img)
# Out:
# True

# %%
# saving the Color Image
cv2.imwrite('lena Color.jpg', color_img)
# Out:
# True

# %% [markdown]
# ### Draw on Images:

# %%
# Drawing Line On image:
line_img = cv2.line(color_img,(0,0), (100,100), (255,0,0),6)  #BGR
cv2.imshow("Line Image", line_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# When We Work on CNN there is RGB, And When We Work On OpenCv, there is BGR

# %%
# Drawing Line On rectangle:
rect_img = cv2.rectangle(color_img, (100,100),(200,200),(255,0,255), -2)
cv2.imshow("Rectangle Image", rect_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Generate a Blank Canvas :

# %%
canvas = np.zeros([400, 400], np.uint8)
cv2.imshow("Black Canvas",canvas)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
canvas.shape
# Out:
# (400, 400)

# %%
canvas.size
# Out:
# 160000

# %%
canvas2 = cv2.rectangle(canvas,(100,100),(300,300),(255,255,255),-1)
cv2.imshow("Solid Rectangle",canvas2)
cv2.waitKey(2000)
cv2.destroyAllWindows()

# %% [markdown]
# ### Segregating the  the Channels:

# %%
color_img = cv2.imread("lena.jpg",1)
b,g,r = cv2.split(color_img)

# Blue Channel
cv2.imshow("Blue Channel",b)
cv2.waitKey(0)
cv2.destroyAllWindows()

# Green Channel
cv2.imshow("Green Channel",g)
cv2.waitKey(0)
cv2.destroyAllWindows()

# Red Channel
cv2.imshow("Red Channel",r)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Merge the channels

# %%
# Merge Channel
cv2.imshow("Merge Channel",cv2.merge((b,g,r)))
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Task 1: On the box color image segregate the channels and save them and share the images

# %% [markdown]
# ### Resize the image :

# %%
color_img.shape
# Out:
# (512, 512, 3)

# %%
color_img_resize = cv2.resize(color_img, (400,400))
print(color_img_resize.shape)
cv2.imshow("Resized Image",color_img_resize)
cv2.waitKey(1000)
cv2.destroyAllWindows()
# Out:
# (400, 400, 3)

# %% [markdown]
# ### Adding Images:

# %%
# Here in Canvas, 
# np.ones() means it will give a white color canvas in the output and 
# np.zeros() means it will give a black color canvas in the output

# %%
canvas3 = 150*np.ones([400,400],np.uint8)
canvas3 = cv2.rectangle(canvas3,(150,150),(250,250),(0,0,0),-1)
cv2.imshow("Canvas 3",canvas3)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Combination of Canvas2 And Canvas3:

# %%
result = cv2.add(canvas2,canvas3)
cv2.imshow("Result",result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Thresholding

# %%
grad = cv2.imread("gradient.png",0)
cv2.imshow("Gradient",grad)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
threshold_value1, thresh_img1 = cv2.threshold(grad,127,255,cv2.THRESH_BINARY)
cv2.imshow("Binary Thresholding",thresh_img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# This IS inverse of the above threshold image
threshold_value2, thresh_img2 = cv2.threshold(grad,127,255,cv2.THRESH_BINARY_INV)
cv2.imshow("Inverse Binary Thresholding",thresh_img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
threshold_value3, thresh_img3 = cv2.threshold(grad,127,255,cv2.THRESH_TRUNC)
cv2.imshow("Inverse Binary Thresholding",thresh_img3)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Finding Pixels in an image using a range:

# %%
tsignal = cv2.imread("traffic signal.jpg",1)
tsignal_resized = cv2.resize(tsignal,(400,400))
cv2.imshow("Signal",tsignal_resized)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
lower = np.array([0,0,50])
higher = np.array([100,100,255])
red_part = cv2.inRange(tsignal_resized,lower,higher) 
cv2.imshow("Red Pixel Only",red_part)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Task 2: Find the Yellow and Green Parts as well

# %% [markdown]
# ### Filters from Scratch:

# %%
shape = cv2.imread("shape.jpg",1)
cv2.imshow("Shapes",shape)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
shape.shape
# Out:
# (648, 1152, 3)

# %%
# Converting a color image to gray scale
shape_bw = cv2.cvtColor(shape,cv2.COLOR_BGR2GRAY)
print(shape.shape,shape_bw.shape,sep="\n")
# Out:
# (648, 1152, 3)
# (648, 1152)

# %%
cv2.imshow("Black and white shapes",shape_bw)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
vertical_fltr = np.tile(np.array([-1,0,1]),(3,1))
print(vertical_fltr)
# Out:
# [[-1  0  1]
#  [-1  0  1]
#  [-1  0  1]]

# %%
horizontal_fltr = np.array([[-1,-1,-1],[0,0,0],[1,1,1]])
print(horizontal_fltr)
# Out:
# [[-1 -1 -1]
#  [ 0  0  0]
#  [ 1  1  1]]

# %%
h = shape_bw.shape[0]
w = shape_bw.shape[1]

i=0
j=0

shape_vertical_fltr=[]

while i<h-2:
    t = []
    j=0
    while j<w-2:
        t.append(np.multiply(shape_bw[i:i+3,j:j+3],vertical_fltr).sum())
        j+=1
    shape_vertical_fltr.append(t)
    i+=1

# %%
shape_vertical = np.array(shape_vertical_fltr)

# %%
shape_vertical.shape
# Out:
# (646, 1150)

# %%
plt.imshow(shape_vertical)

# %%
shape_vertical_final = shape_vertical.astype(np.uint8)

# %%
cv2.imshow("Vertical",shape_vertical_final)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite("shape vertical filter.jpg",shape_vertical_final)
# plt.imsave(r"data\shape vertical filter.jpg",shape_vertical_final)
# Out:
# True

# %%
h = shape_bw.shape[0]
w = shape_bw.shape[1]

i=0
j=0

shape_horizontal_fltr=[]

while i<h-2:
    t = []
    j=0
    while j<w-2:
        t.append(np.multiply(shape_bw[i:i+3,j:j+3],horizontal_fltr).sum())
        j+=1
    shape_horizontal_fltr.append(t)
    i+=1

shape_horizontal = np.array(shape_horizontal_fltr)

# %%
plt.imshow(shape_horizontal)

# %%
shape_horizontal_final = shape_horizontal.astype(np.uint8)

# %%
cv2.imshow("Horizontal",shape_horizontal_final)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Applying both filter together

# %%
vertical_result = cv2.filter2D(shape_bw,-1,vertical_fltr)
horizontal_result = cv2.filter2D(shape_bw,-1,horizontal_fltr)

# combine
combined_result = np.abs(vertical_result) + np.abs(horizontal_result)

cv2.imshow("Combined Result",combined_result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Task 3
# fltr1 = np.tile(np.array([-1, -1, -1, -1, 0, 1, 1, 1, 1]), (9, 1))
# fltr2 = fltr.transpose()
# print(fltr)
# Apply the above filters on house.jpg and 3x3 filter on house.jpg
#
# compare and contrast the results you get

# %% [markdown]
# ## LAPLACIAN FILTER

# %%
person = cv2.imread("lena.jpg",1)
cv2.imshow("Lena",person)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
person_lap = cv2.Laplacian(person,cv2.CV_64F)
person_lap = np.uint8(np.absolute(person_lap))
cv2.imshow("Laplacian Filter",person_lap)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Gaussian Filter
# 3x3 Gaussian kernel

# image.png

# %%
person = cv2.imread("lena.jpg",1)
cv2.imshow("Lena",person)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
lena_gauss = cv2.GaussianBlur(person,(7,7),0)
cv2.imshow("Gaussian Filter",lena_gauss)
cv2.imshow("lena",person)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Median Blur

# %%
person = cv2.imread("lena.jpg",1)
cv2.imshow("Lena",person)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
lena_median = cv2.medianBlur(person,5)
cv2.imshow("Median Filter",lena_median)
cv2.imshow("lena",person)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
lena = cv2.imread("lena.jpg",1)
lena_bilateral = cv2.bilateralFilter(lena,9,75,75)
cv2.imshow("Lena",lena)
cv2.imshow("Bilateral Filter",lena_bilateral)
cv2.imshow("Median Filter",lena_median)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Canny Filter
# Reduces the noise => Gaussian Smoothing
#
# Sobel Filter
#
# local maxima

# %%
pumpkin = cv2.imread("halloween.jpg",1)
cv2.imshow("Pumpkin",pumpkin)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
canny_pumpkin = cv2.Canny(pumpkin,100,200,apertureSize=5,L2gradient=True)
cv2.imshow("Canny Pumpkin",canny_pumpkin)
cv2.imshow("Pumpkin",pumpkin)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Working with Video using OpenCV

# %%
# import numpy as np
# import cv2
# from random import randint

# def get_color():
#     return (randint(0,255),randint(0,255),randint(0,255))

# cap = cv2.VideoCapture(0)
# # 0 : webcam windows
# # 1 2 3 : for external webcam
# # -1 : linux OS or Macbook

# frame_save = None
# while True:
#     _, frame = cap.read()
    
#     frame_save = frame
    
#     grey = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    
#     res = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
#     res = np.array(res,dtype=np.float64)
#     res = cv2.transform(res, np.matrix([[0.393,0.769,0.189],
#                                         [0.349,0.686,0.168],[0.272,0.534,0.131]]))
#     res[np.where(res>255)]=255
#     res = np.array(res,dtype=np.uint8)
#     res = cv2.cvtColor(res,cv2.COLOR_RGB2BGR)
    
#     cv2.putText(frame,"Color",(50,50),cv2.FONT_HERSHEY_SIMPLEX,1,get_color(),2)
#     cv2.putText(grey,"Grey",(50,50),cv2.FONT_HERSHEY_SIMPLEX,1,get_color(),2)
#     cv2.putText(res,"Filter",(50,50),cv2.FONT_HERSHEY_SIMPLEX,1,get_color(),2)
#     cv2.imshow("Grey Camera",grey)
#     cv2.imshow("Color Camera",frame)
#     cv2.imshow("Sepia Camera",res)
#     if cv2.waitKey(1) & 0xFF==ord('q'):
#         break

# cap.release()
# cv2.destroyAllWindows()

# cv2.imwrite(r"data\greyPhoto.jpg",grey)
# cv2.imwrite(r"data\ColorPhoto.jpg",frame)
# cv2.imwrite(r"data\SepiaPhoto.jpg",res)

# %%
# IF want then Use it the above given code
